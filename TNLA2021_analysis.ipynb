# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('Tamil_Nadu_State_Elections_2021_Details.csv')

df.head()
# Out:
#   Constituency         Candidate                                     Party  \
# 0      Alandur     T.M.Anbarasan                 Dravida Munnetra Kazhagam
# 1      Alandur      B.Valarmathi  All India Anna Dravida Munnetra Kazhagam
# 2      Alandur            N.Raja               Desiya Makkal Sakthi Katchi
# 3      Alandur    G Kamalakannan                Tamil Nadu Ilangyar Katchi
# 4      Alandur  Dr.R.Karthikeyan                       Naam Tamilar Katchi
#
#    EVM_Votes  Postal_Votes  Total_Votes  %_of_Votes  \
# 0     115777          1008       116785       49.12
# 1      75634           580        76214       32.06
# 2        261             4          265        0.11
# 3       1096             9         1105        0.46
# 4      16453            53        16506        6.94
#
#    Tot_Constituency_votes_polled  Tot_votes_by_parties  Winning_votes  \
# 0                         237751              17430100         116785
# ...

# %%
df.rename(columns={'%_of_Votes': 'vote_percentage','EVM_Votes':'evm_votes','Postal_Votes':'postal_votes'}, inplace=True)

# %%
new_df= df.groupby('Party')

# %%
new_df.head()
# Out:
#             Constituency          Candidate  \
# 0                Alandur      T.M.Anbarasan
# 1                Alandur       B.Valarmathi
# 2                Alandur             N.Raja
# 3                Alandur     G Kamalakannan
# 4                Alandur   Dr.R.Karthikeyan
# ...                  ...                ...
# 4121  Coimbatore (South)   RAGHUL GANDHI .K
# 4122  Coimbatore (South)  VIVEK SUBRAMANIAM
# 4123  Coimbatore (South)         VELLIMALAI
# 4193              Thalli             RAVI.G
# 4231         Vilavancode  VASANTHEESWARAN E
#
#                                          Party  evm_votes  postal_votes  \
# 0                    Dravida Munnetra Kazhagam     115777          1008
# 1     All India Anna Dravida Munnetra Kazhagam      75634           580
# 2                  Desiya Makkal Sakthi Katchi        261             4
# 3                   Tamil Nadu Ilangyar Katchi       1096             9
# ...
